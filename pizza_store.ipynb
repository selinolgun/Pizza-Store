# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import pandas as pd

# Kullanacağımız kütüphaneleri içe aktardık.

form = tk.Tk()
form.title("Pizza Store - Selin Olgun - Sonay Ilıca")
form.geometry("300x550+100+100")
form.resizable(False, False)
form.state("normal")

# Penceremizi istediğimiz özelliklerde oluşturduk.

ana_sayfa_resim = ImageTk.PhotoImage(Image.open("AnaSayfa.jpg"))
menü_resim = ImageTk.PhotoImage(Image.open("Menü.jpg"))
siparis_ver_resim = ImageTk.PhotoImage(Image.open("SiparişVer.jpg"))
odeme_resim = ImageTk.PhotoImage(Image.open("Ödeme.jpg"))
sonuc_resim = ImageTk.PhotoImage(Image.open("Sonuç.jpg"))

# Anasayfa, menü, sipariş ver, ödeme ve sonuç ekranı arka plan için jpg dosyalarını içe aktardık.

ana_sayfa_bg = tk.Label(form, image= ana_sayfa_resim).pack()

# Anasayfa için oluşturduğumuz arka planı yerleştirdik.

def remove_widgets():
    for widget in form.winfo_children():
        widget.destroy()

		# Pencerede açık bütün widgetleri kaldıracak bir fonksiyon tanımladık.

def menu_icerik():
	menü_bg = tk.Label(form, image= menü_resim).pack()
	hamur = tk.Label(form, text= "Pastry:", font= "Ariel 13", fg= "black", bg= "white").place(x=2,y=2)
	ince_hamur = tk.Label(form, text= "Thin Dough - 15 $", font= "Ariel 10", bg= "white").place(x=32,y=22)
	orta_hamur = tk.Label(form, text= "Medium Dough - 20 $", font= "Ariel 10", bg= "white").place(x=32,y=42)
	kalın_hamur = tk.Label(form, text= "Thick Dough - 25 $", font= "Ariel 10", bg= "white").place(x=32,y=62)
	sos = tk.Label(form, text= "Sauce:", font= "Ariel 13", bg= "white").place(x=2,y=82)
	domates = tk.Label(form, text= "Tomato Sauce - 5 $", font= "Ariel 10", bg= "white").place(x=32,y=102)
	blue_cheese = tk.Label(form, text= "Blue Cheese Sauce - 7 $", font= "Ariel 10", bg= "white").place(x=32,y=122)
	pesto = tk.Label(form, text= "Pesto Sauce - 6 $", font= "Ariel 10", bg= "white").place(x=32,y=142)
	guacamole = tk.Label(form, text= "Guacamole Sauce - 7 $", font= "Ariel 10", bg= "white").place(x=32,y=162)
	peynir = tk.Label(form, text= "Cheeses:", font= "Ariel 13", bg= "white").place(x=2,y=182)
	mozzarella = tk.Label(form, text= "Mozzarella - 11 $", font= "Ariel 10", bg= "white").place(x=32,y=202)
	edam = tk.Label(form, text= "Edam - 12 $", font= "Ariel 10", bg= "white").place(x=32,y=222)
	chedar = tk.Label(form, text= "Chedar - 10 $", font= "Ariel 10", bg= "white").place(x=32,y=242)
	emmental = tk.Label(form, text= "Emmental - 13 $", font= "Ariel 10", bg= "white").place(x=32,y=262)
	ust_malzeme = tk.Label(form, text= "Upper Materials:", font= "Ariel 13", bg= "white").place(x=2,y=282)
	kapya_biber = tk.Label(form, text= "Capia Pepper - 8 $", font= "Ariel 10", bg= "white").place(x=32,y=302)
	domates = tk.Label(form, text= "Tomato - 6 $", font= "Ariel 10", bg= "white").place(x=32,y=322)
	zeytin = tk.Label(form, text= "Olive - 5 $", font= "Ariel 10", bg= "white").place(x=32,y=342)
	sucuk = tk.Label(form, text= "Sausage - 11 $", font= "Ariel 10", bg= "white").place(x=32,y=362)
	mantar = tk.Label(form, text= "Mushrooms - 9 $", font= "Ariel 10", bg= "white").place(x=32,y=382)
	sosis = tk.Label(form, text= "Bacon - 7 $", font= "Ariel 10", bg= "white").place(x=32,y=402)
	mısır = tk.Label(form, text= "Corn - 5 $", font= "Ariel 10", bg= "white").place(x=32,y=422)
	kuru_sogan = tk.Label(form, text= "Onion - 6 $", font= "Ariel 10", bg= "white").place(x=32,y=442)
	tavuk_eti = tk.Label(form, text= "Chicken Meat - 10 $", font= "Ariel 10", bg= "white").place(x=32,y=462)
	jambon = tk.Label(form, text= "Ham - 8 $", font= "Ariel 10", bg= "white").place(x=32,y=482)
	brokoli = tk.Label(form, text= "Broccoli - 7 $", font= "Ariel 10", bg= "white").place(x=32,y=502)
	karnabahar = tk.Label(form, text= "Cauliflower - 6 $", font= "Ariel 10", bg= "white").place(x=32,y=522)
	def ana_sayfa():
		remove_widgets()
		ana_sayfa_bg = tk.Label(form, image= ana_sayfa_resim).pack()
		menu_button = tk.Button(form, command= menu, text= "Menu", width= 20, height= 4).place(x= 80, y= 130)
		siparis_button = tk.Button(form, command= siparis, text= "Order", width= 20, height= 4).place(x= 80, y= 230)
	ana_s= tk.Button(form, command= ana_sayfa, text= "Home Page", width= 10, height= 2).place(x= 210, y= 500)
def menu():
    remove_widgets()
    menu_icerik()
menu_button = tk.Button(form, command= menu, text= "Menu", width= 20, height= 4).place(x= 80, y= 130)

# Menü içeriğini hazırladık, def ile ana sayfaya butonları ekledik.

a = tk.IntVar()
a.set(0)
b = tk.IntVar()
b.set(0)
c = tk.IntVar()
c.set(0)
d = tk.IntVar()
d.set(0)
e = tk.IntVar()
e.set(0)
f = tk.IntVar()
f.set(0)
g = tk.IntVar()
g.set(0)
h = tk.IntVar()
h.set(0)
ı = tk.IntVar()
ı.set(0)
i = tk.IntVar()
i.set(0)
j = tk.IntVar()
j.set(0)
k = tk.IntVar()
k.set(0)
l = tk.IntVar()
l.set(0)
m = tk.IntVar()
m.set(0)
n = tk.IntVar()
n.set(0)
p = tk.IntVar()
p.set(0)
r = tk.IntVar()
r.set(0)
s = tk.IntVar()
s.set(0)
t = tk.IntVar()
t.set(0)
u = tk.IntVar()
u.set(0)
v = tk.IntVar()
v.set(0)
y = tk.IntVar()
y.set(0)
z = tk.IntVar()
z.set(0)

# Menü açıldığında hiçbir ürünün seçilmemiş olduğunu ve checkbuttonlardan veri çekebilmek için değer atamaları yaptık.

def hamur_s():
	siparis_ver_bg = tk.Label(form, image= siparis_ver_resim).pack()
	hamur_sec = tk.Label(form, text= "Pastry:", font= "Ariel 13", bg= "white").place(x=2,y=2)
	ince_hamur_check = tk.Checkbutton(form, text= "Thin Dough", font= "Ariel 10", bg= "white", variable= a).place(x=2,y=22)
	orta_hamur_check = tk.Checkbutton(form, text= "Medium Dough", font= "Ariel 10", bg= "white", variable= b).place(x=2,y=42)
	kalın_hamur_check = tk.Checkbutton(form, text= "Thick Dough", font= "Ariel 10", bg= "white", variable= c).place(x=2,y=62)
	sos_sec = tk.Label(form, text= "Sauces:", font= "Ariel 13", bg= "white").place(x=2,y=82)
	domates_sos_check = tk.Checkbutton(form, text= "Tomato Sauce", font= "Ariel 10", bg= "white", variable= d).place(x=2,y=102)
	blue_cheese_sos_check = tk.Checkbutton(form, text= "Blue Cheese Sauce", font= "Ariel 10", bg= "white", variable= e).place(x=2,y=122)
	pesto_sos_check = tk.Checkbutton(form, text= "Pesto Sauce", font= "Ariel 10", bg= "white", variable= f).place(x=2,y=142)
	guacamole_sos_check = tk.Checkbutton(form, text= "Guacamole Sauce", font= "Ariel 10", bg= "white", variable= g).place(x=2,y=162)
	peynir_sec = tk.Label(form, text= "Cheeses:", font= "Ariel 13", bg= "white").place(x=2,y=182)
	mozarella_check = tk.Checkbutton(form, text= "Mozarella", font= "Ariel 10", bg= "white", variable= h).place(x=2,y=202)
	edam_check = tk.Checkbutton(form, text= "Edam", font= "Ariel 10", bg= "white", variable= ı).place(x=2,y=222)
	chedar_check = tk.Checkbutton(form, text= "Chedar", font= "Ariel 10", bg= "white", variable= i).place(x=2,y=242)
	emmental_check = tk.Checkbutton(form, text= "Emmental", font= "Ariel 10", bg= "white", variable= j).place(x=2,y=262)
	üst_malzeme_sec = tk.Label(form, text= "Upper Materials:", font= "Ariel 13", bg= "white").place(x=2,y=282)
	kapya_biber_check = tk.Checkbutton(form, text= "Capia Pepper", font= "Ariel 10", bg= "white", variable= k).place(x=2,y=302)
	domates_check = tk.Checkbutton(form, text= "Tomato", font= "Ariel 10", bg= "white", variable= l).place(x=2,y=322)
	zeytin_check = tk.Checkbutton(form, text= "Olive", font= "Ariel 10", bg= "white", variable= m).place(x=2,y=342)
	sucuk_check = tk.Checkbutton(form, text= "Sausage", font= "Ariel 10", bg= "white", variable= n).place(x=2,y=362)
	mantar_check = tk.Checkbutton(form, text= "Mushrooms", font= "Ariel 10", bg= "white", variable= p).place(x=2,y=382)
	sosis_check = tk.Checkbutton(form, text= "Bacon", font= "Ariel 10", bg= "white", variable= r).place(x=2,y=402)
	mısır_check = tk.Checkbutton(form, text= "Corn", font= "Ariel 10", bg= "white", variable= s).place(x=2,y=422)
	kuru_sogan_check = tk.Checkbutton(form, text= "Onion", font= "Ariel 10", bg= "white", variable= t).place(x=2,y=442)
	tavuk_eti_check = tk.Checkbutton(form, text= "Chicken Meat", font= "Ariel 10", bg= "white", variable= u).place(x=2,y=462)
	jambon_check = tk.Checkbutton(form, text= "Ham", font= "Ariel 10", bg= "white", variable= v).place(x=2,y=482)
	brokoli_check = tk.Checkbutton(form, text= "Broccoli", font= "Ariel 10", bg= "white", variable= y).place(x=2,y=502)
	karnabahar_check = tk.Checkbutton(form, text= "Cauliflower", font= "Ariel 10", bg= "white", variable= z).place(x=2,y=522)
	def ana_sayfa():
		remove_widgets()
		ana_sayfa_bg = tk.Label(form, image= ana_sayfa_resim).pack()
		menu_button = tk.Button(form, command= menu, text= "Menu", width= 20, height= 4).place(x= 80, y= 130)
		siparis_button = tk.Button(form, command= siparis, text= "Order", width= 20, height= 4).place(x= 80, y= 230)
	ana_s= tk.Button(form, command= ana_sayfa, text= "Home Page", width= 10, height= 2).place(x= 210, y= 500)

	# Order buton seçeneğinin içine pizza içeriklerini aktardık.

	def ödeme():
		if (a.get() == 1 and b.get() == 0 and c.get() == 0) or (b.get() == 1 and a.get() == 0 and c.get() == 0) or (c.get() == 1 and b.get() == 0 and a.get() == 0):
			remove_widgets()
			siparis_ver_bg = tk.Label(form, image= odeme_resim).pack()
			isim_text = tk.StringVar()
			isim_label = tk.Label(form, text= "Name Surname:", font= "Ariel 10", bg= "white").place(x= 50, y= 150)
			isim_entry = tk.Entry(form, bg= "orange", textvariable= isim_text).place(x= 120, y= 180)
			kart_text = tk.StringVar()
			kart_label = tk.Label(form, text= "Credit Card Number:", font= "Ariel 10", bg= "white").place(x= 50, y= 210)
			kart_entry = tk.Entry(form, bg= "orange", textvariable= kart_text).place(x= 120, y= 240)
			kart_isim_text = tk.StringVar()
			kart_isim_label = tk.Label(form, text= "Owner of the Credit Card:", font= "Ariel 10", bg= "white").place(x= 50, y= 270)
			kart_isim_entry = tk.Entry(form, bg= "orange", textvariable= kart_isim_text).place(x= 120, y= 300)
			kart_cvc2_text = tk.StringVar()
			kart_cvc2_label = tk.Label(form, text= "Card's CVV Code:", font= "Ariel 10", bg= "white").place(x= 50, y= 330)
			kart_cvc2_entry = tk.Entry(form, bg= "orange", textvariable= kart_cvc2_text).place(x= 120, y= 360)

			# Ödeme ekranını oluşturduk.

			def bitir():
				isim = isim_text.get()
				kart = kart_text.get()
				kart_isim = kart_isim_text.get()
				kart_cvc2 = kart_cvc2_text.get()
				an = datetime.now()
				remove_widgets()
				sonuc_bg = tk.Label(form, image= sonuc_resim).pack()
				acıklama0 = tk.Label(form, text= f"{isim}", font= "Ariel 10", bg= "yellow").place(x= 40, y= 180)
				acıklama1 = tk.Label(form, text= "Order Received", font= "Ariel 10", bg= "yellow").place(x= 40, y= 200)
				acıklama2 = tk.Label(form, text= f"Order Entry Date: {an}", font= "Ariel 10", bg= "yellow").place(x= 40, y= 220)
				acıklama3 = tk.Label(form, text= "Order Description:", font= "Ariel 10", bg= "yellow").place(x= 40, y= 240)
				ürün = []
				if a.get() == 1:
					ürün.append("Thin Dough")
				if b.get() == 1:
					ürün.append("Medium Dough")
				if c.get() == 1:
					ürün.append("Thick Dough")
				if d.get() == 1:
					ürün.append("Tomato Sauce")
				if e.get() == 1:
					ürün.append("Blue Cheese Sauce")
				if f.get() == 1:
					ürün.append("Pesto Sauce")
				if g.get() == 1:
					ürün.append("Guacamole Sauce")
				if h.get() == 1:
					ürün.append("Mozzarella")
				if ı.get() == 1:
					ürün.append("Edam")
				if i.get() == 1:
					ürün.append("Chedar")
				if j.get() == 1:
					ürün.append("Emmental")
				if k.get() == 1:
					ürün.append("Capia Pepper")
				if l.get() == 1:
					ürün.append("Tomato")
				if m.get() == 1:
					ürün.append("Olive")
				if n.get() == 1:
					ürün.append("Sausage")
				if p.get() == 1:
					ürün.append("Mushrooms")
				if r.get() == 1:
					ürün.append("Bacon")
				if s.get() == 1:
					ürün.append("Corn")
				if t.get() == 1:
					ürün.append("Onion")
				if u.get() == 1:
					ürün.append("Chicken Meat")
				if v.get() == 1:
					ürün.append("Ham")
				if y.get() == 1:
					ürün.append("Broccoli")
				if z.get() == 1:
					ürün.append("Cauliflower")
				ürün1 = list(ürün)
				ürün2 = pd.DataFrame(ürün1, columns= ["Ingredients"])
				mask = ürün2.iloc[:]
				acıklama4 = tk.Label(form, text= f"{mask}", font= "Ariel 10", bg= "yellow").place(x= 80, y= 280)
				fiyat = 0
				if a.get() == 1:
					fiyat += 15
				if b.get() == 1:
					fiyat += 20
				if c.get() == 1:
					fiyat += 25
				if d.get() == 1:
					fiyat += 5
				if e.get() == 1:
					fiyat += 7
				if f.get() == 1:
					fiyat += 6
				if g.get() == 1:
					fiyat += 7
				if h.get() == 1:
					fiyat += 11
				if ı.get() == 1:
					fiyat += 12
				if i.get() == 1:
					fiyat += 10
				if j.get() == 1:
					fiyat += 13
				if k.get() == 1:
					fiyat += 8
				if l.get() == 1:
					fiyat += 6
				if m.get() == 1:
					fiyat += 5
				if n.get() == 1:
					fiyat += 11
				if p.get() == 1:
					fiyat += 9
				if r.get() == 1:
					fiyat += 7
				if s.get() == 1:
					fiyat += 5
				if t.get() == 1:
					fiyat += 6
				if u.get() == 1:
					fiyat += 10
				if v.get() == 1:
					fiyat += 8
				if y.get() == 1:
					fiyat += 7
				if z.get() == 1:
					fiyat += 6
				acıklama5 = tk.Label(form, text= f"Price: {fiyat} $", font= "Ariel 10", bg= "yellow").place(x= 80, y= 260)

				# Siparişi veren kişiye dair bilgiler eklendi. Siparişi bitir ekranını ve fiyat listesini ekledik.

				veri = open("Orders_Database.csv", "a")
				veri.write(f"{an};{isim};{kart};{kart_isim};{kart_cvc2};{ürün};{fiyat}\n")

				# Bitirme ekranındaki veriyi Orders_Database.csv dosyasına aktardık.

				def ana_sayfa():
					remove_widgets()
					ana_sayfa_bg = tk.Label(form, image= ana_sayfa_resim).pack()
					menu_button = tk.Button(form, command= menu, text= "Menu", width= 20, height= 4).place(x= 80, y= 130)
					siparis_button = tk.Button(form, command= siparis, text= "Order", width= 20, height= 4).place(x= 80, y= 230)
					a.set(0)
					b.set(0)
					c.set(0)
					d.set(0)
					e.set(0)
					f.set(0)
					g.set(0)
					h.set(0)
					ı.set(0)
					i.set(0)
					j.set(0)
					k.set(0)
					l.set(0)
					m.set(0)
					n.set(0)
					p.set(0)
					r.set(0)
					s.set(0)
					t.set(0)
					u.set(0)
					v.set(0)
					y.set(0)
					z.set(0)
				ana_s= tk.Button(form, command= ana_sayfa, text= "Home Page", width= 10, height= 2).place(x= 210, y= 500)

				# Ana sayfaya geri dönüşte malzemelerin işaretlemesini sıfırladık.

			menu_button = tk.Button(form, command= bitir, text= "Complete Payment", width= 15, height= 2).place(x= 170, y= 390)
		else:
			messagebox.showinfo(title= "Dough Type Warning", message= "Please select a dough type.")

			# Pizza hamurunu fazla ya da hiç seçmemesi durumunda uyarı mesaj kutusunu aktifleştirdik.

	ödeme_s= tk.Button(form, command= ödeme, text= "Pay", width= 10, height= 2).place(x= 210, y= 450)
def siparis():
	remove_widgets()
	hamur_s()
siparis_button = tk.Button(form, command= siparis, text= "Order", width= 20, height= 4).place(x= 80, y= 230)

# Ödeme ekranı ve sipariş butonu eklendi.

form.mainloop()

# Pencerenin biz kapatana kadar ekranda kalmasını sağladık.
